# %%
import pandas as pd

# %%
scale =pd.read_csv('describe_all_scale.csv')
stat = pd.read_csv('describe_all_stat.csv')

# %%
res = pd.concat([scale, stat], axis=0)
res.columns
# Out:
# Index(['task_round', 'column_name', 'sample_size', 'mean', 'std', 'std_error',
#        'ci_lower', 'ci_upper', 'min', 'max'],
#       dtype='object')

# %%
sort = ["sus", "effect", "easy", "easy_learn", "satisfaction", "mouse_distance", "mouse_click", "keyboard_press", "duration"]
res = res.sort_values(by=["column_name", "task_round"], key=lambda x: x.map({k: i for i, k in enumerate(sort)})).reindex(["column_name", "task_round", "sample_size", "mean", "std", "std_error", "ci_lower", "ci_upper", "min", "max"], axis=1).reset_index(drop=True)
res
# Out:
#        column_name  task_round  sample_size           mean           std  \
# 0              sus           0           15      49.666667     16.428295
# 1              sus           1           15      76.500000      9.119576
# 2           effect           0           15      35.186667      7.961061
# 3           effect           1           15      49.480000      4.167685
# 4             easy           0           15      39.626667     10.431712
# 5             easy           1           15      61.666667      5.206492
# 6       easy_learn           0           15      16.120000      4.425261
# 7       easy_learn           1           15      25.520000      1.629397
# 8     satisfaction           0           15      29.133333      8.081804
# 9     satisfaction           1           15      46.600000      2.800000
# 10  mouse_distance           0           15  161544.933333  47012.283963
# 11  mouse_distance           1           15   17693.066667   8779.771375
# 12     mouse_click           0           15     326.333333     67.089658
# 13     mouse_click           1           15      11.800000      6.862458
# 14  keyboard_press           0           15     373.200000     98.690222
# 15  keyboard_press           1           15    1028.666667    238.502737
# 16        duration           0           15     763.424600    169.761690
# 17        duration           1           15     428.398067    106.502454
#
#        std_error       ci_lower       ci_upper        min         max
# 0       4.241768      37.039592      62.293742     20.000      87.500
# 1       2.354664      69.490534      83.509466     60.000      90.000
# 2       2.055537      29.067656      41.305677     20.600      47.800
# 3       1.076092      46.276644      52.683356     43.800      54.600
# 4       2.693457      31.608670      47.644663     22.000      60.200
# 5       1.344310      57.664866      65.668467     51.000      67.200
# 6       1.142597      12.718667      19.521333      8.600      23.600
# 7       0.420708      24.267617      26.772383     21.000      26.600
# 8       2.086713      22.921517      35.345149     18.000      42.000
# 9       0.722957      44.447871      48.752129     40.000      49.000
# 10  12138.519524  125410.469686  197679.396980  98043.000  269443.000
# 11   2266.927221   10944.780839   24441.352494   3804.000   43405.000
# 12     17.322475     274.767049     377.899618    228.000     470.000
# 13      1.771879       6.525395      17.074605      2.000      26.000
# 14     25.481706     297.344969     449.055031    237.000     580.000
# 15     61.581142     845.349292    1211.984041    753.000    1643.000
# 16     43.832280     632.942796     893.906404    474.630    1143.378
# 17     27.498815     346.538418     510.257715    259.809     609.363

# %%
res["task_round"] = res["task_round"].map({ 0: "WIMP", 1: "M-CAT"})

# %%
res = res.rename(columns={"column_name": "因变量", "task_round": "任务组", "sample_size": "样本量", "mean": "均值", "std": "标准差", "std_error": "标准误", "ci_lower": "99% 置信区间下限", "ci_upper": "99% 置信区间上限", "min": "最小值", "max": "最大值"})

# %%
res["因变量"] = res["因变量"].map({"sus": "SUS 评分", "effect": "USE 有效性评分", "easy": "USE 易用性", "easy_learn": "USE 易学性评分", "satisfaction": "USE 满意度评分", "mouse_distance": "鼠标移动距离", "mouse_click": "鼠标点击次数", "keyboard_press": "键盘按键次数", "duration": "任务时长"})
res  = res.round(3)
res
# Out:
#           因变量    任务组  样本量          均值        标准差        标准误  99% 置信区间下限  \
# 0      SUS 评分   WIMP   15      49.667     16.428      4.242      37.040
# 1      SUS 评分  M-CAT   15      76.500      9.120      2.355      69.491
# 2   USE 有效性评分   WIMP   15      35.187      7.961      2.056      29.068
# 3   USE 有效性评分  M-CAT   15      49.480      4.168      1.076      46.277
# 4     USE 易用性   WIMP   15      39.627     10.432      2.693      31.609
# 5     USE 易用性  M-CAT   15      61.667      5.206      1.344      57.665
# 6   USE 易学性评分   WIMP   15      16.120      4.425      1.143      12.719
# 7   USE 易学性评分  M-CAT   15      25.520      1.629      0.421      24.268
# 8   USE 满意度评分   WIMP   15      29.133      8.082      2.087      22.922
# 9   USE 满意度评分  M-CAT   15      46.600      2.800      0.723      44.448
# 10     鼠标移动距离   WIMP   15  161544.933  47012.284  12138.520  125410.470
# 11     鼠标移动距离  M-CAT   15   17693.067   8779.771   2266.927   10944.781
# 12     鼠标点击次数   WIMP   15     326.333     67.090     17.322     274.767
# 13     鼠标点击次数  M-CAT   15      11.800      6.862      1.772       6.525
# 14     键盘按键次数   WIMP   15     373.200     98.690     25.482     297.345
# 15     键盘按键次数  M-CAT   15    1028.667    238.503     61.581     845.349
# 16       任务时长   WIMP   15     763.425    169.762     43.832     632.943
# 17       任务时长  M-CAT   15     428.398    106.502     27.499     346.538
#
#     99% 置信区间上限        最小值         最大值
# 0       62.294     20.000      87.500
# 1       83.509     60.000      90.000
# 2       41.306     20.600      47.800
# 3       52.683     43.800      54.600
# 4       47.645     22.000      60.200
# 5       65.668     51.000      67.200
# 6       19.521      8.600      23.600
# 7       26.772     21.000      26.600
# 8       35.345     18.000      42.000
# 9       48.752     40.000      49.000
# 10  197679.397  98043.000  269443.000
# 11   24441.352   3804.000   43405.000
# 12     377.900    228.000     470.000
# 13      17.075      2.000      26.000
# 14     449.055    237.000     580.000
# 15    1211.984    753.000    1643.000
# 16     893.906    474.630    1143.378
# 17     510.258    259.809     609.363

# %%
res.to_csv("describe_all.csv", index=False, float_format="%.3f")
